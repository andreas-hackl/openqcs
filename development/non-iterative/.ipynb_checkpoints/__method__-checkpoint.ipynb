# %%
import numpy as np

import openqcs as op
import openqcs.tools as t
import openqcs.spinchain as sp
import openqcs.qcirc as q
import openqcs.iterativ as it

import pyqcs

import matplotlib.pyplot as plt

# %%
a = 0.5
b = 0.5

dt = 0.05

H = sp.H_(a,b)
T = sp.T_(H, dt)
